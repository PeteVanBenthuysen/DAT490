# %% [markdown]
# # EDA Exploration
# Various functions to use for EDA

# %% [markdown]
# This is a function that I use for EDA projects. They are based on material from a course I took in 2024 with UT Austin
#
#
# Muthuraman, K. (2024). Supervised Learning Techniques. Week 3. Austin. Retrieved 2024, from https://olympus.mygreatlearning.com/courses/103402/modules/items/5866521?pb_id=16824.

# %%
# Function to plot histogram and boxplot for a numeric column
def histogram_boxplot(data, feature, figsize=(15, 10), kde=False, bins=None):
    """
    Boxplot and histogram combined.

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (15,10))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid = 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # Creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # Boxplot with a mean indicator
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # Histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--", label="Mean"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-", label="Median"
    )  # Add median to the histogram
    ax_hist2.legend()
    plt.show()

# Automatically detect numeric columns and plot
def plot_numeric_columns(dataframe):
    """
    Automatically generates boxplots and histograms for all numeric columns in the dataframe.
    
    dataframe: pandas DataFrame
    """
    # Select numeric columns
    numeric_columns = dataframe.select_dtypes(include='number')

    # Drop rows with missing values in numeric columns (optional)
    numeric_columns = numeric_columns.dropna()

    # Generate plots for each numeric column
    numeric_columns.apply(
        lambda col: histogram_boxplot(data=dataframe, feature=col.name), axis=0
    )

plot_numeric_columns(df)

# %% [markdown]
# ## Pandas Profiling Function
#
# Automatic Pythonic Data Report. Takes a look at each variable and interaction within the dataset. Great overview, slicing and splitting capabilities. Includes correlation analysis as well. Can replace plotly use in EDA

# %%
#import pandas as pd
#from ydata_profiling import ProfileReport

Profile= ProfileReport(df, title= 'Name of Analysis')

#runs the profile and renders the html report
Profile

#download and export as html
Profile.to_file('EDASummaryExport.html')
